# %% [markdown]
# <a href="https://colab.research.google.com/github/jenishta8/Machine-Learning/blob/main/hierarchial%20clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np

# %%
x = np.array([[1, 2], [2, 3], [3, 3], [6, 5], [8, 8], [10, 10]])

# %%
c=AgglomerativeClustering(n_clusters=2,linkage='ward')
c.fit(x)
# Out:
# AgglomerativeClustering()

# %%
print(c.labels_)
# Out:
# [0 0 0 0 1 1]

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt
Z = sch.linkage(x, method='ward')

sch.dendrogram(Z)
plt.show()
